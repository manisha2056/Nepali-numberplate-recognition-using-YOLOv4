# %%
# !nvidia-smi
# Out:
# Mon Feb 28 15:52:51 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!ls '/content/drive/MyDrive/character'

# %%
#!unzip '/content/drive/MyDrive/character/characterlabel.zip' -d'/content/drive/MyDrive/character'

# %%
#!git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/My Drive/character/darknet'

# %%
#%cd /content/drive/MyDrive/character/darknet

# %%
#!make

# %%
#%cd /content/drive/MyDrive/character

# %%
#!python characterlabel/creating-files-data-and-name.py

# %%
#!python characterlabel/creating-train-and-test-txt-files.py

# %%
#!wget 'https://pjreddie.com/media/files/dartknet53.conv.74' '/content/drive/MyDrive/character'

# %%
# %cd /content/drive/MyDrive/character/darknet
# Out:
# /content/drive/MyDrive/character/darknet

# %%
# !chmod +x ./darknet

# %%
#!./darknet detector train /content/drive/MyDrive/character/characterlabel/labelled_data.data /content/drive/MyDrive/character/darknet/cfg/yolov4-tiny.cfg /content/drive/MyDrive/character/darknet/backup/yolov4-tiny_last.weights -dont_show

# %%
#!./darknet detector map /content/drive/MyDrive/character/characterlabel/labelled_data.data /content/drive/MyDrive/character/darknet/cfg/yolov4-tiny.cfg /content/drive/MyDrive/character/darknet/backup/yolov4-tiny_10000.weights

# %%
# !./darknet detector  test /content/drive/MyDrive/character/characterlabel/labelled_data.data /content/drive/MyDrive/character/darknet/cfg/yolov4-tiny.cfg /content/drive/MyDrive/character/darknet/backup/yolov4-tiny_20000.weights /content/drive/MyDrive/character/darknet/data/a653.jpg -thresh 0.3 -dont_show
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 2    416 x 416 x   3 ->  208 x 208 x  32 0.075 BF
#    1 conv     64       3 x 3/ 2    208 x 208 x  32 ->  104 x 104 x  64 0.399 BF
#    2 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#    3 route  2 		                       1/2 ->  104 x 104 x  32
#    4 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    5 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    6 route  5 4 	                           ->  104 x 104 x  64
# ...
